# %% [markdown]
# <a href="https://colab.research.google.com/github/pammyyAnn/12-13_activity/blob/main/12_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/FINAL_ACT1_PAM/movies_metadata.csv'
df = pd.read_csv(filename)
df
# Out:
# <ipython-input-4-869a67d9c0be>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename)
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %%
df[['adult']].head()
# Out:
#    adult
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
df[['budget', 'genres']].head()
# Out:
#      budget                                             genres
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4         0                     [{'id': 35, 'name': 'Comedy'}]

# %%
df[['budget', 'genres', 'homepage', 'id']].tail()
# Out:
#       budget                                             genres  \
# 45461      0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462      0                      [{'id': 18, 'name': 'Drama'}]
# 45463      0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464      0                                                 []
# 45465      0                                                 []
#
#                                    homepage      id
# 45461  http://www.imdb.com/title/tt6209470/  439050
# 45462                                   NaN  111109
# 45463                                   NaN   67758
# 45464                                   NaN  227506
# 45465                                   NaN  461257

# %%
df['revenue'].head()
# Out:
# 0    373554033.0
# 1    262797249.0
# 2            0.0
# 3     81452156.0
# 4     76578911.0
# Name: revenue, dtype: float64

# %%
type(df['genres'].head())
# Out:
# pandas.core.series.Series

# %%
df['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %%
df['adult'][0:10]
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: adult, dtype: object

# %%
df.id.head()
# Out:
# 0      862
# 1     8844
# 2    15602
# 3    31357
# 4    11862
# Name: id, dtype: object

# %%
df.loc[:, ['homepage']].head()
# Out:
#                                homepage
# 0  http://toystory.disney.com/toy-story
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %%
df.loc[:, ['revenue']].head()
# Out:
#        revenue
# 0  373554033.0
# 1  262797249.0
# 2          0.0
# 3   81452156.0
# 4   76578911.0

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df['homepage'].value_counts()
# Out:
# http://www.georgecarlin.com                       12
# http://www.wernerherzog.com/films-by.html          7
# http://breakblade.jp/                              6
# http://www.thehungergames.movie/                   4
# http://www.crownintlpictures.com/tztitles.html     4
#                                                   ..
# http://wn.com/Flypaper_%282011_film%29             1
# http://www.theperfectgamemovie.com                 1
# http://www.arthurchristmas.com/                    1
# http://happyfeettwo.warnerbros.com/index.html      1
# http://www.imdb.com/title/tt6209470/               1
# Name: homepage, Length: 7673, dtype: int64

# %%
df['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                         5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                        3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                   2723
# []                                                                                                                                    2442
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                       1301
#                                                                                                                                       ...
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 99, 'name': 'Documentary'}]             1
# ...

# %%
df['id'].value_counts()
# Out:
# 141971    3
# 168538    2
# 25541     2
# 15028     2
# 11115     2
#          ..
# 72272     1
# 1549      1
# 10171     1
# 38996     1
# 461257    1
# Name: id, Length: 45436, dtype: int64

# %%
original_name = df['genres']=='budget	'
original_name.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: genres, dtype: bool

# %%
df[original_name].head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.loc[original_name, :].head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                         5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                        3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                   2723
# []                                                                                                                                    2442
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                       1301
#                                                                                                                                       ...
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 35, 'name': 'Comedy'}, {'id': 99, 'name': 'Documentary'}]             1
# ...

# %%
df = df.loc[original_name, :]
df['genres'].value_counts()
# Out:
# Series([], Name: genres, dtype: int64)

# %%
df['id'].value_counts()
# Out:
# Series([], Name: id, dtype: int64)

# %%
budget_filter = df['genres']==0.03
df = df.loc[budget_filter, :]
df['genres'].value_counts(dropna = False)
# Out:
# Series([], Name: genres, dtype: int64)

# %%
df = df.loc[budget_filter & original_name, :]
df
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['budget']==0.03
# Out:
# Series([], Name: budget, dtype: bool)

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 24 columns]
